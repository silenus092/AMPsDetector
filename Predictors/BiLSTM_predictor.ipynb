# %%
# for keras 2.3.1
from tensorflow.keras.models import load_model

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve,auc

import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
#os.environ["CUDA_VISIBLE_DEVICES"]="-1"    
# CustomCNN.Adam.512_1211.V2.h5
# CustomCNN.RMSprop.512_1211.V2.h5

deployed_path = "/mnt/vdb/thesis/best_model_BLSTM.V4.h5"
import tensorflow as tf
learner = load_model(deployed_path)
#with tf.device('/cpu:0'):
#    learner = load_model(deployed_path)
# Out:
# WARNING:tensorflow:Layer bilstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer bilstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer bilstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
def toPredictDF(path,to_dir,existing_result):
    appended_pkl = []
    for infile in glob.glob(path):
        #print("Read:",infile)
        file_name = os.path.basename(infile)
        result_path=to_dir+"/"+file_name.replace("pkl", "ML.pkl")
        if result_path in existing_result :
        # print("found then skip : " , result)
            continue
        else:
            df = pd.read_pickle(infile)
            ready_df =df[[ "reps"]]
            df_new = ready_df.reps.apply(pd.Series).astype(np.float64)
            df_new.columns = df_new.columns.astype(str)
            dl = learner.dls.test_dl(df_new)
            _preds,_none ,_y = learner.get_preds(dl=dl, with_decoded=True)
            df.drop(columns=['reps','length'],inplace =True)
            df['class'] = _y
            #print("Save:",result_path)
            df.to_pickle(result_path)
    print("Complete")

def mergeDF(path,to_dir,file_name):
    appended_data = []
    for infile in glob.glob(path):
        #print(infile)
        data = pd.read_pickle(infile)
        # store DataFrame in list
        appended_data.append(data)
    result_path=to_dir+"/"+file_name
    print("Save:",result_path)
    appended_data = pd.concat(appended_data)
    appended_data.sort_values(by=['ID'], inplace=True)
    appended_data.to_pickle(result_path)
    return appended_data

def predict_CNN(path,to_dir,existing_result):
    appended_pkl = []
    for infile in glob.glob(path):  
     #print("Read:",infile)
        file_name = os.path.basename(infile)
        result_path=to_dir+"/"+file_name.replace("pkl", "ML.pkl")
        if result_path in existing_result :
        # print("found then skip : " , result)
            continue
        else:
            df = pd.read_pickle(infile)
            ready_df =df[[ "reps"]]
            
            X= np.array(df['reps'].to_list())
            X_test = np.reshape(X,(X.shape[0],X.shape[1],1))
            y_probas = learner.predict(X_test)
            threshold = 0.5
            _y = np.where(y_probas > threshold, 1, 0)
            df.drop(columns=['reps'],inplace =True)
            df['class'] = _y
            #print("Save:",result_path)
            df.to_pickle(result_path) 

    print("Complete")

# %%
# summarize model.
learner.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1900, 1)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 1900, 64)          2624
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 76, 64)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 76, 128)           57472
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 19, 128)           0
# _________________________________________________________________
# dense (Dense)                (None, 19, 1211)          156219
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 1211)          0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 19, 128)           653312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19, 128)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 2432)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2433
# =================================================================
# Total params: 872,060
# Trainable params: 872,060
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## DECockRoach

# %%
path = "/mnt/vdb/DECockroach/cd100/result_4/result_BILSTM"
if not os.path.exists(path):
    os.makedirs(path)

existing_result = []
for infile in glob.glob("/mnt/vdb/DECockroach/cd100/result_4/result_BILSTM/*.pkl"):
    # print(infile)
    existing_result.append(infile)
print(len(existing_result))
# Out:
# 0

# %%
# Predict
predict_CNN("/mnt/vdb/DECockroach/cd100/reps/*.pkl","/mnt/vdb/DECockroach/cd100/result_4/result_BILSTM",existing_result)
# Out:
# Complete

# %%
# write result
result_df =mergeDF("/mnt/vdb/DECockroach/cd100/result_4/result_BILSTM/*.pkl","/mnt/vdb/DECockroach/cd100/result_4/result_BILSTM","DECockroach.len15.MLResult.plk")
result_df
# Out:
# Save: /mnt/vdb/DECockroach/cd100/result_4/result_BILSTM/DECockroach.len15.MLResult.plk
#          ID  length  class
# 0         0      17      0
# 1         1      17      1
# 2         3      18      0
# 3         4      30      0
# 4         5      17      1
# ..      ...     ...    ...
# 199  894298      17      0
# 200  894299      19      0
# 201  894303      17      1
# 202  894304      17      0
# 203  894305      28      0
#
# [626569 rows x 3 columns]

# %%
result_df[result_df["class"]== 1]
# Out:
#          ID  length  class
# 1         1      17      1
# 4         5      17      1
# 5         6      24      1
# 8         9      19      1
# 9        10      18      1
# ..      ...     ...    ...
# 186  894277      48      1
# 191  894285      33      1
# 193  894288      17      1
# 195  894293      28      1
# 201  894303      17      1
#
# [214416 rows x 3 columns]

# %%
result_df[result_df["class"]== 1]
# Out:
#          ID  length  class
# 9        10      18      1
# 10       12      20      1
# 13       16      19      1
# 14       17      17      1
# 16       19      17      1
# ..      ...     ...    ...
# 193  894288      17      1
# 195  894293      28      1
# 199  894298      17      1
# 201  894303      17      1
# 202  894304      17      1
#
# [283272 rows x 3 columns]

# %% [markdown]
# ## BAT

# %%
path ="/mnt/vdb/Bat/cd100/result_4/result_BILSTM"
if not os.path.exists(path):
    os.makedirs(path)

existing_result = []
for infile in glob.glob("/mnt/vdb/Bat/cd100/result_4/result_BILSTM/*.pkl"):
    # print(infile)
    existing_result.append(infile)
print(len(existing_result))
# Out:
# 0

# %%
# Predict
predict_CNN("/mnt/vdb/Bat/cd100/reps/*.pkl",path,existing_result)
# Out:
# Complete

# %%
# write result
result_df =mergeDF(path+"/*.pkl",path,"Bat.len10.MLResult.plk")
result_df
# Out:
# Save: /mnt/vdb/Bat/cd100/result_4/result_BILSTM/Bat.len10.MLResult.plk
#           ID  length  class
# 0          9     275      1
# 1         19      47      1
# 2         32     151      1
# 3         54     199      1
# 4         61     152      1
# ..       ...     ...    ...
# 74  12568817      51      1
# 75  12568833      45      1
# 76  12568849     117      0
# 77  12568850     174      1
# 78  12568985     229      1
#
# [422796 rows x 3 columns]

# %%
result_df[result_df["class"]== 1]
# Out:
#                                                      ID  length  class
# 1                                   SOAP.k25.C303708.p1     102      1
# 2                                   SOAP.k25.C304032.p1     103      1
# 3                                   SOAP.k25.C304284.p1     104      1
# 4                                   SOAP.k25.C304386.p1     104      1
# 5                                   SOAP.k25.C305552.p1     108      1
# ...                                                 ...     ...    ...
# 1000    Velvet.k61.NODE_783_length_328_cov_36.378048.p1     106      1
# 1001   Velvet.k61.NODE_8470_length_279_cov_15.172043.p1     105      1
# 1002   Velvet.k61.NODE_9141_length_765_cov_44.260132.p2     233      1
# 1003  Velvet.k61.NODE_9415_length_1250_cov_53.216000.p1     367      1
# 1004   Velvet.k61.NODE_9432_length_496_cov_51.205647.p1     163      1
#
# [9695 rows x 3 columns]

# %% [markdown]
# # TransPI

# %% [markdown]
# ## BAT

# %%
path ="/mnt/vdb/Bat/transpi/result_4/result_BILSTM"
if not os.path.exists(path):
    os.makedirs(path)

existing_result = []
for infile in glob.glob("/mnt/vdb/Bat/transpi/result_4/result_BILSTM/*.pkl"):
    # print(infile)
    existing_result.append(infile)
print(len(existing_result))
# Out:
# 0

# %%
# Predict
predict_CNN("/mnt/vdb/Bat/transpi/reps/*.pkl","/mnt/vdb/Bat/transpi/result_4/result_BILSTM",existing_result)
# Out:
# Complete

# %%
# write result
result_df =mergeDF("/mnt/vdb/Bat/transpi/result_4/result_BILSTM/*.pkl","/mnt/vdb/Bat/transpi/result_4/result_BILSTM","Bat.len10.MLResult.plk")
result_df
# Out:
# Save: /mnt/vdb/Bat/transpi/result_4/result_BILSTM/Bat.len10.MLResult.plk
#                                                      ID  length  class
# 0                                   SOAP.k25.C303246.p1     101      1
# 1                                   SOAP.k25.C303708.p1     102      1
# 2                                   SOAP.k25.C304032.p1     103      1
# 3                                   SOAP.k25.C304284.p1     104      1
# 4                                   SOAP.k25.C304386.p1     104      1
# ...                                                 ...     ...    ...
# 1000    Velvet.k61.NODE_783_length_328_cov_36.378048.p1     106      1
# 1001   Velvet.k61.NODE_8470_length_279_cov_15.172043.p1     105      0
# 1002   Velvet.k61.NODE_9141_length_765_cov_44.260132.p2     233      1
# 1003  Velvet.k61.NODE_9415_length_1250_cov_53.216000.p1     367      1
# 1004   Velvet.k61.NODE_9432_length_496_cov_51.205647.p1     163      1
#
# [11005 rows x 3 columns]

# %%
result_df[result_df["class"] == 1]
# Out:
#                                                      ID  length  class
# 0                                   SOAP.k25.C303246.p1     101      1
# 1                                   SOAP.k25.C303708.p1     102      1
# 2                                   SOAP.k25.C304032.p1     103      1
# 3                                   SOAP.k25.C304284.p1     104      1
# 4                                   SOAP.k25.C304386.p1     104      1
# ...                                                 ...     ...    ...
# 999    Velvet.k61.NODE_7367_length_630_cov_23.734921.p1     193      1
# 1000    Velvet.k61.NODE_783_length_328_cov_36.378048.p1     106      1
# 1002   Velvet.k61.NODE_9141_length_765_cov_44.260132.p2     233      1
# 1003  Velvet.k61.NODE_9415_length_1250_cov_53.216000.p1     367      1
# 1004   Velvet.k61.NODE_9432_length_496_cov_51.205647.p1     163      1
#
# [9335 rows x 3 columns]

# %%
result_df[result_df["class"] == 1]
# Out:
#                                                      ID  length  class
# 0                                   SOAP.k25.C303246.p1     101      1
# 1                                   SOAP.k25.C303708.p1     102      1
# 2                                   SOAP.k25.C304032.p1     103      1
# 3                                   SOAP.k25.C304284.p1     104      1
# 4                                   SOAP.k25.C304386.p1     104      1
# ...                                                 ...     ...    ...
# 999    Velvet.k61.NODE_7367_length_630_cov_23.734921.p1     193      1
# 1000    Velvet.k61.NODE_783_length_328_cov_36.378048.p1     106      1
# 1001   Velvet.k61.NODE_8470_length_279_cov_15.172043.p1     105      1
# 1003  Velvet.k61.NODE_9415_length_1250_cov_53.216000.p1     367      1
# 1004   Velvet.k61.NODE_9432_length_496_cov_51.205647.p1     163      1
#
# [9440 rows x 3 columns]

# %% [markdown]
# ## DECockroach

# %%
path ="/mnt/vdb/DECockroach/transpi/result_4/result_BILSTM"
if not os.path.exists(path):
    os.makedirs(path)


existing_result = []
for infile in glob.glob("/mnt/vdb/DECockroach/transpi/result_4/result_BILSTM/*.pkl"):
    # print(infile)
    existing_result.append(infile)
print(len(existing_result))
# Out:
# 0

# %%
# Predict
predict_CNN("/mnt/vdb/DECockroach/transpi/reps/*.pkl","/mnt/vdb/DECockroach/transpi/result_4/result_BILSTM",existing_result)
# Out:
# Complete

# %%
# write result
result_df =mergeDF("/mnt/vdb/DECockroach/transpi/result_4/result_BILSTM/*.pkl","/mnt/vdb/DECockroach/transpi/result_4/result_BILSTM","DECockroach.len15.MLResult.plk")
result_df
# Out:
# Save: /mnt/vdb/DECockroach/transpi/result_4/result_BILSTM/DECockroach.len15.MLResult.plk
#                                                    ID  length  class
# 0                                 SOAP.k25.C372231.p1     102      1
# 1                                 SOAP.k25.C373809.p1     104      1
# 2                                 SOAP.k25.C379695.p1      95      1
# 3                                 SOAP.k25.C382451.p1     116      1
# 4                                 SOAP.k25.C383053.p1     104      1
# ..                                                ...     ...    ...
# 54  Velvet.k37.NODE_9552_length_1035_cov_12.333333.p1     102      1
# 55  Velvet.k37.NODE_9713_length_2207_cov_17.057997.p1     627      1
# 56   Velvet.k37.NODE_9748_length_894_cov_40.512302.p1     124      1
# 57   Velvet.k37.NODE_9800_length_726_cov_45.530304.p1     221      1
# 58  Velvet.k37.NODE_9843_length_1025_cov_50.463413.p1     191      1
#
# [17559 rows x 3 columns]

# %%
result_df[result_df["class"] == 0]
# Out:
#                                                    ID  length  class
# 9                                 SOAP.k25.C387573.p1     124      0
# 19                                SOAP.k25.C397059.p1     115      0
# 23                                SOAP.k25.C397729.p1     126      0
# 31                                SOAP.k25.C405333.p1     144      0
# 32                                SOAP.k25.C405897.p1     129      0
# ..                                                ...     ...    ...
# 13  Velvet.k37.NODE_71696_length_822_cov_50.759125.p1     258      0
# 19  Velvet.k37.NODE_73436_length_1641_cov_16.12309...     514      0
# 28   Velvet.k37.NODE_7963_length_783_cov_48.134098.p1     157      0
# 44   Velvet.k37.NODE_8670_length_780_cov_48.342308.p1     254      0
# 46   Velvet.k37.NODE_87364_length_444_cov_7.360360.p1     142      0
#
# [2609 rows x 3 columns]
